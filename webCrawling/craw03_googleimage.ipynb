# %% [markdown]
# https://wingetgui.com/apps?id=Git.Git&v=2.35.1.2
#
# pip install git+https://github.com/Joeclinton1/google-images-download.git

# %%
#우리는 keywords, limit만 조금씩 변경해서 사용하면 된다.
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"Polar bears,baloons,Beaches","limit":20,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = Polar bears
# Evaluating...
# Starting Download...
# Image URL: https://files.worldwildlife.org/wwfcmsprod/images/Polar_bear_on_ice_in_Svalbard_Norway_WW294883/hero_small/85px6g3dhv_Polar_bear_on_ice_in_Svalbard_Norway_WW294883.jpg
# Completed Image ====> 1.85px6g3dhv_polar_bear_on_ice_in_svalbard_norway_ww294883.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/6/66/Polar_Bear_-_Alaska_%28cropped%29.jpg
# Completed Image ====> 2.polar_bear_-_alaska_%28cropped%29.jpg
# Image URL: https://i.natgeofe.com/k/32a45b33-5468-40e4-8b94-a7489871729b/polar-bear-cub-on-mom_2x1.jpg
# Completed Image ====> 3.polar-bear-cub-on-mom_2x1.jpg.webp
# Image URL: https://ichef.bbci.co.uk/news/976/cpsprodpb/12DF7/production/_113530377_bears_kt-miller.jpg
# Completed Image ====> 4._113530377_bears_kt-miller.jpg
# Image URL: https://managersoffice.net/wp-content/uploads/2021/02/babypolarbears.jpg
# ...

# %%
arguments = {"keywords":"Lake","limit":10,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = Lake
# Evaluating...
# Starting Download...
# Image URL: https://cdn.britannica.com/97/158797-050-ABECB32F/North-Cascades-National-Park-Lake-Ann-park.jpg?w=400&h=300&c=crop
# Completed Image ====> 1.north-cascades-national-park-lake-ann-park.jpg
# Image URL: https://media.cntraveler.com/photos/5eb1ce0c79397e1bac70bdf5/5:4/w_4710,h_3768,c_limit/Lake-Pahoe-GettyImages-559514223.jpg
# Completed Image ====> 2.lake-pahoe-gettyimages-559514223.jpg
# Image URL: https://i.hurimg.com/i/hdn/75/0x0/5dcd630a0f25441794d60a1c.jpg
# Completed Image ====> 3.5dcd630a0f25441794d60a1c.jpg
# Image URL: https://www.collinsdictionary.com/images/full/lake_281848937_1000.jpg
# Completed Image ====> 4.lake_281848937_1000.jpg
# Image URL: https://www.treehugger.com/thmb/DHIuSei-2EzIfUuzYEzAM6No_kE=/3004x2253/smart/filters:no_upscale()/craterlake-821559daf61a4aa1855084e09546b3de.jpg
# Completed Image ====> 5.craterlake-821559daf61a4aa1855084e09546b3de.jpg
# ...

# %%
from IPython.display import Image

Image('1.png',width=500)

# %%
arguments = {"keywords":"워너원 강다니엘, 엑소 백현, 박보검, 송중기,워너원 황민현, 엑소 시우민, 강동원,\
              이종석,이준기, 마동석, 조진웅, 조세호, 안재홍, 윤두준, 이민기, 김우빈, 육성재, 공유,\
              방탄소년단 정국, 아이콘 바비, 워너원 박지훈, 엑소 수호", "limit":30,"print_urls":True, 'format' : 'jpg'}
paths = response.download(arguments)   #passing the arguments to the function
print(paths)
# Out:
# Item no.: 1 --> Item name = \uc6cc\ub108\uc6d0 \uac15\ub2e4\ub2c8\uc5d8
# Evaluating...
# Starting Download...
# Image URL: http://www.chungnamilbo.com/news/photo/201804/444549_61416_3855.jpg
# Completed Image ====> 1.444549_61416_3855.jpg
# Image URL: https://newsimg.sedaily.com/2018/11/19/1S790WUYN0_1.jpg
# Completed Image ====> 2.1s790wuyn0_1.jpg
# Image URL: https://img.huffingtonpost.com/asset/5d4bb6393b0000a912dae926.jpeg?cache=7JGhvMLvbp&ops=scalefit_630_noupscale
# Completed Image ====> 3.5d4bb6393b0000a912dae926.jpeg
# Image URL: http://res.heraldm.com/content/image/2017/08/19/20170819000036_0.jpg
# Completed Image ====> 4.20170819000036_0.jpg
# Image URL: https://imgbntnews.hankyung.com/bntdata/images/photo/201811/d430548556ee219afa7f965117f9e6c9.jpg
# Completed Image ====> 5.d430548556ee219afa7f965117f9e6c9.jpg
# Image URL: https://photo.jtbc.joins.com/news/2018/11/19/20181119163812585.jpg
# Completed Image ====> 6.20181119163812585.jpg
# ...
